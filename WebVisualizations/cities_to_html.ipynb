# %%
import pandas as pd

# %%
cities = pd.read_csv('cities.csv')

# %%
cities
# Out:
#      Unnamed: 0      City Name  Latitude  Longitude  Max Temp (F)  Humidity  \
# 0             0    storforshei     66.40      14.52         55.40        54
# 1             1         avarua    -21.21    -159.78         71.60        78
# 2             2        chicama     -7.84     -79.15         72.10        57
# 3             3       la rioja     42.25      -2.50         86.00        25
# 4             4      sahuaripa     29.05    -109.23         94.89        34
# ..          ...            ...       ...        ...           ...       ...
# 553         553       flinders    -34.58     150.86         52.00        88
# 554         554          kidal     18.44       1.41        104.68         7
# 555         555        pathein     16.78      94.73         80.98        88
# 556         556  makakilo city     21.35    -158.09         80.60        65
# 557         557           bagn     60.82       9.55         45.00        71
#
#      Cloudiness  Wind Speed Country        Date
# ...

# %%
cities.drop(columns = ['Unnamed: 0'], inplace = True)

# %%
cities
# Out:
#          City Name  Latitude  Longitude  Max Temp (F)  Humidity  Cloudiness  \
# 0      storforshei     66.40      14.52         55.40        54          75
# 1           avarua    -21.21    -159.78         71.60        78          74
# 2          chicama     -7.84     -79.15         72.10        57          40
# 3         la rioja     42.25      -2.50         86.00        25           0
# 4        sahuaripa     29.05    -109.23         94.89        34          73
# ..             ...       ...        ...           ...       ...         ...
# 553       flinders    -34.58     150.86         52.00        88          93
# 554          kidal     18.44       1.41        104.68         7           0
# 555        pathein     16.78      94.73         80.98        88         100
# 556  makakilo city     21.35    -158.09         80.60        65           1
# 557           bagn     60.82       9.55         45.00        71          95
#
#      Wind Speed Country        Date
# ...

# %%
cities_html = cities.to_html()

# %%
print(cities_html)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>City Name</th>
#       <th>Latitude</th>
#       <th>Longitude</th>
#       <th>Max Temp (F)</th>
#       <th>Humidity</th>
#       <th>Cloudiness</th>
#       <th>Wind Speed</th>
#       <th>Country</th>
#       <th>Date</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>storforshei</td>
#       <td>66.40</td>
#       <td>14.52</td>
#       <td>55.40</td>
#       <td>54</td>
#       <td>75</td>
#       <td>9.17</td>
#       <td>NO</td>
#       <td>1594145702</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>avarua</td>
#       <td>-21.21</td>
#       <td>-159.78</td>
#       <td>71.60</td>
#       <td>78</td>
#       <td>74</td>
#       <td>10.29</td>
#       <td>CK</td>
#       <td>1594145682</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>chicama</td>
#       <td>-7.84</td>
#       <td>-79.15</td>
# ...
